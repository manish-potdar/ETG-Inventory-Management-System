# %%
import json
from datetime import datetime

# %%
fd = open('Records.json', 'r')
r = fd.read()
fd.close()

Record = json.loads(r)

fd = open('Sales.json', 'r')
s = fd.read()
fd.close()

sales = json.loads(s)

# %%
def purchase():
    n=-1
    while n!=0:
        print("\t\t\t***Welcome to the Manish's Groecry store!***\n")
        print("0 - Exit \n1 - Fruits \n2 - Vegetables \n3 - flour \n4 - Condiments-spices \n5 - Fish-Shelfish \n6 - Baverages\n")
        n=int(input("Enter the No. as mentionned above what you want to buy from our store : "))
        if n!=0:
            cust_name=str(input("Enter Your Name : "))
            cust_mob_no=int(input("Enter the Mobile Number : "))
            cust_city=str(input("Enter Your City Name : "))
        #Fruits
        if n==1:
            print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
            print("ID  - Prducts \n101 - Bananas \n102 - Apples \n103 - Grapes \n104 - Oranges \n105 - Pineapple \n")
            a=str(input("\nEnter the id of prodcut which you want to buy......"))
            q=int(int(input("\nEnter the quantity how much you want :")))
            if q<Record['Fruits'][a]['quantity']:
                for i in Record['Fruits']:
                    if i==a:
                        print("\n*--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*")
                        print('     Product ID - ',i)
                        print('     Product Name - ',Record['Fruits'][i]['Name'])
                        print('     Product price - '+str(Record['Fruits'][i]['price'])+' /',Record['Fruits'][i]['unit'])
                        print('     Total Amount - '+ str(Record['Fruits'][i]['price']*q))
                        print("*--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*\n")
                        Record['Fruits'][i]['quantity']=Record['Fruits'][i]['quantity']-q
                        now = datetime.now()
                        current_time = now.strftime("%H:%M:%S")
                        sales[len(sales)+1]={'Name':cust_name,'contact':cust_mob_no,'Address':cust_city,'product':Record['Fruits'][i]['Name'],'amount':Record['Fruits'][i]['price']*q,'time':current_time}
            else:
                print(f"\nWe are Sorry your quantity is too large we only have {Record['Fruits'][a]['quantity']}\n")
        #Vegetables
        elif n==2:
            print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
            print("ID  - Prducts \n201 - Bananas \n202 - Tomatoes \n203 - Onions \n204 - Carrots \n205 - Garlic \n")
            a=str(input("\nEnter the id of prodcut which you want to buy......"))
            q=int(int(input("\nEnter the quantity how much you want :")))
            if q<Record['Vegetables'][a]['quantity']:
                for i in Record['Vegetables']:
                    if i==a:
                        print("\n*--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*")
                        print('     Product ID - ',i)
                        print('     Product Name - ',Record['Vegetables'][i]['Name'])
                        print('     Product price - '+str(Record['Vegetables'][i]['price'])+' /',Record['Vegetables'][i]['unit'])
                        print('     Total Amount - '+ str(Record['Vegetables'][i]['price']*q))
                        print("*--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*\n")
                        Record['Vegetables'][i]['quantity']=Record['Vegetables'][i]['quantity']-q
                        now = datetime.now()
                        current_time = now.strftime("%H:%M:%S")
                        sales[len(sales)+1]={'Name':cust_name,'contact':cust_mob_no,'Address':cust_city,'product':Record['Vegetables'][i]['Name'],'amount':Record['Vegetables'][i]['price']*q,'time':current_time}
            else:
                print(f"\nWe are Sorry your quantity is too large we only have {Record['Vegetables'][a]['quantity']}\n")
        #flour
        elif n==3:
            print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
            print("ID  - Prducts \n301 - Whole Wheat flour \n302 - Barley flour \n303 - Jawar flour \n304 - Rice \n305 - Bajara flour \n")
            a=str(input("\nEnter the id of prodcut which you want to buy......"))
            q=int(int(input("\nEnter the quantity how much you want :")))
            if q<Record['flour'][a]['quantity']:
                for i in Record['flour']:
                    if i==a:
                        print("\n*--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*")
                        print('     Product ID - ',i)
                        print('     Product Name - ',Record['flour'][i]['Name'])
                        print('     Product price - '+str(Record['flour'][i]['price'])+' /',Record['flour'][i]['unit'])
                        print('     Total Amount - '+ str(Record['flour'][i]['price']*q))
                        print("*--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*\n")
                        Record['flour'][i]['quantity']=Record['flour'][i]['quantity']-q
                        now = datetime.now()
                        current_time = now.strftime("%H:%M:%S")
                        sales[len(sales)+1]={'Name':cust_name,'contact':cust_mob_no,'Address':cust_city,'product':Record['flour'][i]['Name'],'amount':Record['flour'][i]['price']*q,'time':current_time}
            else:
                print(f"\nWe are Sorry your quantity is too large we only have {Record['flour'][a]['quantity']}\n")
        #Condiments-spices
        elif n==4:
            print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
            print("ID  - Prducts \n401 - Salt \n402 - Sugar \n403 - Pepper \n404 - Ketchup \n405 - Mayonnaise \n")
            a=str(input("\nEnter the id of prodcut which you want to buy......"))
            q=int(int(input("\nEnter the quantity how much you want :")))
            if q<Record['Condiments-spices'][a]['quantity']:
                for i in Record['Condiments-spices']:
                    if i==a:
                        print("\n*--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*")
                        print('     Product ID - ',i)
                        print('     Product Name - ',Record['Condiments-spices'][i]['Name'])
                        print('     Product price - '+str(Record['Condiments-spices'][i]['price'])+' /',Record['Condiments-spices'][i]['unit'])
                        print('     Total Amount - '+ str(Record['Condiments-spices'][i]['price']*q))
                        print("*--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*\n")
                        Record['Condiments-spices'][i]['quantity']=Record['Condiments-spices'][i]['quantity']-q
                        now = datetime.now()
                        current_time = now.strftime("%H:%M:%S")
                        sales[len(sales)+1]={'Name':cust_name,'contact':cust_mob_no,'Address':cust_city,'product':Record['Condiments-spices'][i]['Name'],'amount':Record['Condiments-spices'][i]['price']*q,'time':current_time}
            else:
                print(f"\nWe are Sorry your quantity is too large we only have {Record['Condiments-spices'][a]['quantity']}\n")  
        #Fish-shelfish
        elif n==5:
            print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
            print("ID  - Prducts \n501 - Shrimp \n502 - Crab \n503 - Clams \n504 - Tuna \n505 - Salmon \n")
            a=str(input("\nEnter the id of prodcut which you want to buy......"))
            q=int(int(input("\nEnter the quantity how much you want :")))
            if q<Record['Fish-Shelfish'][a]['quantity']:
                for i in Record['Fish-Shelfish']:
                    if i==a:
                        print("\n*--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*")
                        print('     Product ID - ',i)
                        print('     Product Name - ',Record['Fish-Shelfish'][i]['Name'])
                        print('     Product price - '+str(Record['Fish-Shelfish'][i]['price'])+' /',Record['Fish-Shelfish'][i]['unit'])
                        print('     Total Amount - '+ str(Record['Fish-Shelfish'][i]['price']*q))
                        print("*--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*\n")
                        Record['Fish-Shelfish'][i]['quantity']=Record['Fish-Shelfish'][i]['quantity']-q
                        now = datetime.now()
                        current_time = now.strftime("%H:%M:%S")
                        sales[len(sales)+1]={'Name':cust_name,'contact':cust_mob_no,'Address':cust_city,'product':Record['Fish-Shelfish'][i]['Name'],'amount':Record['Fish-Shelfish'][i]['price']*q,'time':current_time}
            else:
                print(f"\nWe are Sorry your quantity is too large we only have {Record['Fish-Shelfish'][a]['quantity']}\n")
        #Baverages
        elif n==6:
            print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
            print("ID  - Prducts \n601 - Water \n602 - Milk \n603 - Soda \n604 - Beer \n605 - Oil \n")
            a=str(input("\nEnter the id of prodcut which you want to buy......"))
            q=int(int(input("\nEnter the quantity how much you want :")))
            if q<Record['Baverages'][a]['quantity']:
                for i in Record['Baverages']:
                    if i==a:
                        print("\n*--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*")
                        print('     Product ID - ',i)
                        print('     Product Name - ',Record['Baverages'][i]['Name'])
                        print('     Product price - '+str(Record['Baverages'][i]['price'])+' /',Record['Baverages'][i]['unit'])
                        print('     Total Amount - '+ str(Record['Baverages'][i]['price']*q))
                        print("*--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*\n")
                        Record['Baverages'][i]['quantity']=Record['Baverages'][i]['quantity']-q
                        now = datetime.now()
                        current_time = now.strftime("%H:%M:%S")
                        sales[len(sales)+1]={'Name':cust_name,'contact':cust_mob_no,'Address':cust_city,'product':Record['Baverages'][i]['Name'],'amount':Record['Baverages'][i]['price']*q,'time':current_time}
            else:
                print(f"\nWe are Sorry your quantity is too large we only have {Record['flour'][a]['quantity']}\n")

                
                
def addItems():
    m=int(input('\n\n\t\t\t***UPGRADE INVENTORY***\n\n\nEnter 0 for Exit and 1 for continue : '))
    while m!=0:
        if m==1:
            print("\t\t\t***Welcome to the Manish's Groecry store!***\n")
            mat=str(input("Are you adding old material or new(Enter old or new) : "))
            print("\n1 - Fruits \n2 - Vegetables \n3 - flour \n4 - Condiments-spices \n5 - Fish-Shelfish \n6 - Baverages\n")
            n=int(input("Enter the No. as mentionned above in which section you want to add material : "))


            if mat=='old' or mat=='Old':
                #Fruits
                if n==1:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n101 - Bananas \n102 - Apples \n103 - Grapes \n104 - Oranges \n105 - Pineapple \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Fruits'][prod_id]['quantity']=Record['Fruits'][prod_id]['quantity']+prod_qn
                #Vegetables
                elif n==2:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n201 - Bananas \n202 - Tomatoes \n203 - Onions \n204 - Carrots \n205 - Garlic \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Vegetables'][prod_id]['quantity']=Record['Vegetables'][prod_id]['quantity']+prod_qn
                #flour
                elif n==3:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n301 - Whole Wheat flour \n302 - Barley flour \n303 - Jawar flour \n304 - Rice \n305 - Bajara flour \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['flour'][prod_id]['quantity']=Record['flour'][prod_id]['quantity']+prod_qn
                #Condiments-spices
                elif n==4:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n401 - Salt \n402 - Sugar \n403 - Pepper \n404 - Ketchup \n405 - Mayonnaise \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))  
                    Record['Condiments-spices'][prod_id]['quantity']=Record['Condiments-spices'][prod_id]['quantity']+prod_qn
                #Fish-shelfish
                elif n==5:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n501 - Shrimp \n502 - Crab \n503 - Clams \n504 - Tuna \n505 - Salmon \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Fish-Shelfish'][prod_id]['quantity']=Record['Fish-Shelfish'][prod_id]['quantity']+prod_qn
                #Baverages
                elif n==6:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n601 - Water \n602 - Milk \n603 - Soda \n604 - Beer \n605 - Oil \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Baverages'][prod_id]['quantity']=Record['Baverages'][prod_id]['quantity']+prod_qn

            elif mat=='new' or mat=='New':
                prod_name=str(input("Enter the product Name : "))
                prod_price=int(input("\nEnter the Price of each product : "))
                prod_unit=str(input("\nEnter the Unit od product : "))
                #Fruits
                if n==1:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n101 - Bananas \n102 - Apples \n103 - Grapes \n104 - Oranges \n105 - Pineapple \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Fruits'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}

                #Vegetables
                elif n==2:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n201 - Bananas \n202 - Tomatoes \n203 - Onions \n204 - Carrots \n205 - Garlic \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Vegetables'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
                #flour
                elif n==3:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n301 - Whole Wheat flour \n302 - Barley flour \n303 - Jawar flour \n304 - Rice \n305 - Bajara flour \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['flour'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
                #Condiments-spices
                elif n==4:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n401 - Salt \n402 - Sugar \n403 - Pepper \n404 - Ketchup \n405 - Mayonnaise \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))  
                    Record['Condiments-spices'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
                #Fish-shelfish
                elif n==5:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n501 - Shrimp \n502 - Crab \n503 - Clams \n504 - Tuna \n505 - Salmon \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Fish-shelfish'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
                #Baverages
                elif n==6:
                    print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                    print("ID  - Prducts \n601 - Water \n602 - Milk \n603 - Soda \n604 - Beer \n605 - Oil \n")
                    prod_id=str(input("\nEnter the id of prodcut ......"))
                    prod_qn=int(int(input("\nEnter the quantity : ")))
                    Record['Baverages'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
                    
        m=int(input('Enter 0 for Exit and 1 for continue Adding: '))
        
                
purchase()
addItems()
# Out:
# 			***Welcome to the Manish's Groecry store!***
#
# 0 - Exit
# 1 - Fruits
# 2 - Vegetables
# 3 - flour
# 4 - Condiments-spices
# 5 - Fish-Shelfish
# 6 - Baverages
#
# Enter the No. as mentionned above what you want to buy from our store : 1
# Enter Your Name : Manish
# Enter the Mobile Number : 8999137827
# Enter Your City Name : Latur
#
# <--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->
#
# ID  - Prducts
# 101 - Bananas
# 102 - Apples
# 103 - Grapes
# 104 - Oranges
# 105 - Pineapple
#
#
# Enter the id of prodcut which you want to buy......102
#
# Enter the quantity how much you want :5
#
# *--*--*--*--*--*--*--*--*Your bill is this*--*--*--*--*--*--*--*--*
#      Product ID -  102
#      Product Name -  Apples
#      Product price - 50 / per_kg
#      Total Amount - 250
# *--*--*--*--*--*--*--*--*PLASE VISIT AGIAN*--*--*--*--*--*--*--*--*
#
# 			***Welcome to the Manish's Groecry store!***
#
# 0 - Exit
# 1 - Fruits
# 2 - Vegetables
# 3 - flour
# 4 - Condiments-spices
# ...

# %%
rcd = json.dumps(Record)
sl = json.dumps(sales)

fd=open('Records.json','w')
fd.write(rcd)
fd.close()

fd=open('Sales.json','w')
fd.write(sl)
fd.close()

# %%
Record
# Out:
# {'Fruits': {'101': {'Name': 'Bananas',
#    'quantity': 100,
#    'price': 20,
#    'unit': 'per_dozen'},
#   '102': {'Name': 'Apples', 'quantity': 145, 'price': 50, 'unit': 'per_kg'},
#   '103': {'Name': 'Grapes', 'quantity': 90, 'price': 20, 'unit': 'per_kg'},
#   '104': {'Name': 'Oranges', 'quantity': 200, 'price': 25, 'unit': 'per_kg'},
#   '105': {'Name': 'Pineapple',
#    'quantity': 50,
#    'price': 20,
#    'unit': 'per_piece'}},
#  'Vegetables': {'201': {'Name': 'Potatoes',
#    'quantity': 200,
#    'price': 20,
#    'unit': 'per_kg'},
#   '202': {'Name': 'Tomatoes', 'quantity': 200, 'price': 15, 'unit': 'per_kg'},
#   '203': {'Name': 'Onions', 'quantity': 200, 'price': 30, 'unit': 'per_kg'},
#   '204': {'Name': 'Carrots', 'quantity': 100, 'price': 25, 'unit': 'per_kg'},
#   '205': {'Name': 'Garlic', 'quantity': 100, 'price': 30, 'unit': 'per_kg'}},
#  'flour': {'301': {'Name': 'Whole Wheat flour',
#    'quantity': 500,
#    'price': 40,
#    'unit': 'per_kg'},
# ...

# %%
sales
# Out:
# {'1': {'Name': 'Manish',
#   'contact': 8999137827,
#   'Address': 'Latur',
#   'product': 'Apples',
#   'amount': 750,
#   'time': '16:32:24'}}
